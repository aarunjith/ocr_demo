# %%
from pdf2image import convert_from_path

# %%
images = convert_from_path('./templates/w9_form.pdf')

# %%
import numpy as np
from torch_snippets import *

image = np.array(images[0])
show(image)

# %%
images[0].save('./templates/w9_main.jpg')
